# %% [markdown]
# # Metrics definitions

# %% [markdown]
# # Models evaluation

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import yaml
import pickle
import os

import Net.source.utils.experiment_utils as exp
from Net.source.utils.eval_utils import load_eval_results, display_metrics_comparison, plot_mean_matching_accuracy

# %%
test_config_path = 'Net/configs/test.yaml'

# %%
eval_results = load_eval_results(test_config_path, ["Net/runs", "SuperPoint/runs"])

# %%
display_metrics_comparison(eval_results)
# Out:
# /Users/apple/PycharmProjects/Summertime/Net/source/utils/eval_utils.py:401: PerformanceWarning: indexing past lexsort depth may impact performance.
#   METRIC_MAPPING[MS_DUP]: '{:.6f}',
# <style  type="text/css" >
#     #T_50dbe4f8_1900_11ea_b60e_acbc32a5972d th:nth-child(-n+3) {
#           text-align: center;
#           width: 5em;
#           border-style: solid;
#           border-width: 2px;
#           border-color: #6aab7b;
#     }    #T_50dbe4f8_1900_11ea_b60e_acbc32a5972d th:nth-last-child(-n+5) {
#           text-align: center;
#           width: 10em;
#           border-style: solid;
#           border-width: 2px;
#           border-color: #6aab7b;
#     }    #T_50dbe4f8_1900_11ea_b60e_acbc32a5972drow0_col0 {
#             width:  10em;
#             text-align:  center;
#             border-style:  solid;
#             border-width:  1px;
#             border-color:  black;
#             color:  #c2617c;
#              font-weight:  bold;
#             : ;
# ...

# %%
plot_mean_matching_accuracy(eval_results)
